# %% [markdown]
# # Курс «Теория вероятностей и математическая статистика»

# %% [markdown]
# ## Тематический план лекций
#
# |№|Тема|
# |-|-|
# |1|Элементарные исходы. Алгебра случайных событий. Вероятностное пространство. Классическое определение вероятности. Геометрическое определение вероятности. Теорема сложения вероятностей; несовместные события. Условные вероятности. Независимые события и правило умножения вероятностей|
# |2|Формула полной вероятности и формула Байеса. Последовательность независимых испытаний, схема Бернулли.  Дискретные случайные величины. Закон и функция распределения. Числовые характеристики дискретных случайных величин, их свойства. Биномиальное и гипергеометрическое распределение.|
# |3|Система случайных величин. Функция распределения двумерной случайной величины. Независимые случайные величины. Числовые характеристики двумерной случайной величины. Корреляционный момент, коэффициент корреляции. Условные законы распределения.|
# |4|Непрерывные случайные величины. Функция распределения, плотность вероятности. Числовые характеристики непрерывных случайных величин, их свойства. Основные законы распределения: биномиальное, пуассоновское, равномерное, показательное.|
# |5|Нормальный закон распределения. Кривая Гаусса. Вероятность попадания значения нормальной случайной величины в заданный интервал. Правила трех сигм. Распределения $\chi^2$ Пирсона, $t$ (Стьюдента), $F$ (Фишера).|
# |6|Математическая статистика и её задачи. Выборка и её представление. Распределение частот. Эмпирическая функция распределения. Числовые характеристики статистического распределения. Оценка неизвестных параметров. Свойства статистических оценок.|
# |7|Точечные оценки математического ожидания и дисперсии. Доверительные интервалы. Доверительный интервал для математического ожидания при известной и неизвестной дисперсии (для нормального распределения).|
# |8|Проверка статистических гипотез о параметрах нормального закона. Проверка статистической гипотезы о математическом ожидании нормального распределения.|

# %% [markdown]
# ## Тематический план семинаров
#
# |№|Тема|
# |-|-|
# |1|Элементы комбинаторики (комбинаторный принцип умножения и сложения, формулы комбинаторики – перестановки, сочетания и размещения без 2 повторений).|
# |2|События и операции над ними. Вероятность события. Задачи на классическое определение вероятности.|
# |3|Теоремы сложения и умножения вероятностей.|
# |4|Формула полной вероятности. Формула Байеса. |
# |5|Испытания Бернулли. Наивероятнейшее число успехов.|
# |6|Контрольная работа No 1 (Комбинаторика. Вероятностное пространство и базовые формулы)|
# |7|Одномерные дискретные случайные величины. Закон распределения. Функция распределения. Математическое ожидание. Дисперсия. Стандартное отклонение|
# |8|Биномиальное распределение. Гипергеометрическое распределение|
# |9|Одномерные непрерывные случайные величины: плотностью распределения, функцией распределения. Вычисление неизвестных параметров.
# |10|Одномерные непрерывные случайные величины. Математическое ожидание, дисперсия, стандартное отклонение. Вычисление вероятностей событий|
# |11|Двумерные дискретные распределения. Ковариация, коэффициент корреляции, математическое ожидание и дисперсия суммы и произведения двух случайных величин. Условные законы распределения для дискретных случайных величин. Условные математические ожидания и дисперсии.|
# |12|Равномерное распределение на отрезке. Нормальное распределение. Распределения $\chi^2$-Пирсона и Стьюдента.|
# |13|Контрольная №2 (Дискретные и непрерывные распределения)|
# |14|Одномерные выборки. Распределение частот. Выборочные математическое ожидание и дисперсия. Точечные оценки для математического ожидания и дисперсии распределений. Выборочные ковариация и коэффициент корреляции.|
# |15|Проверка статистических гипотез о среднем нормального распределения|
# |16|Контрольная №3 (Оценивание параметров и тестирование гипотез)|
